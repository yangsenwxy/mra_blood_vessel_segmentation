# %% [markdown]
# # Phase 1 - Training of 9 Neural Networks (U-Nets)
#
# Code framework from
# https://www.depends-on-the-definition.com/unet-keras-segmenting-images/ re-used and customised for the purposes of this project

# %%
import os
import math
import numpy as np
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline

import MRASegmentation as mra
import unets.UNetModels as un
import utils.support as sup

from keras.callbacks import EarlyStopping, ModelCheckpoint
# Out:
# /Users/rvh/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.
# No MRA scans are available and nothing can be processed. Set up source data in directory data/source/

# %% [markdown]
# We start by creating an instance for the MRA blood vessel segmentation process. Then we read in all the MRA Record ids for the provided cerebral MRA scans.

# %%
app = mra.MRASegmentation()
mra_all = app.get_mra_source_ids()

# %% [markdown]
# In the first step we create 9 image projections and corresponding projections of ground truth data for all 10 patient records that have been made available for this project.
# IMPORTANT: SET DEBUG=Yes in the ini-file, as data stored in this directory will be used by the training processes of the nine neural networks (UNETS). 1 UNET is trained for each image projection.

# %%
if not app._debug: 
    print ("Set the debug parameter to YES, prior to proceeding with this notebook")
    raise ValueError
else: 
    app.set_up_debug_directories (mra_all)
    for nme in mra_all:  
        app._mra_id = nme
        src = app.get_3d_mra_source(nme) 
        app.get_2d_mra_src_projs(src)
        gt = app.get_3d_mra_gt(nme)
        app.get_2d_mra_gt_projs(gt)
        print('Record '+nme+' processed successfully.')
# Out:
# Record MNI_0656 processed successfully.
# Record MNI_0657 processed successfully.
# Record MNI_0592 processed successfully.
# Record MNI_0643 processed successfully.
# Record MNI_0663 processed successfully.
# Record MNI_0664 processed successfully.
# Record MNI_0590 processed successfully.
# Record MNI_0591 processed successfully.
# Record MNI_0640 processed successfully.
# Record MNI_0648 processed successfully.

# %% [markdown]
# ## Part A - Training

# %% [markdown]
# Split into training, validation and test data sets

# %%
mra_val = ['MNI_0656']   # the manually segmented record is used as validation record during training 
mra_trn = app.get_mra_source_ids()
mra_trn.remove('MNI_0656') # traning data set does not include the manually segmented record
mra_trn.remove('MNI_0663') # removed as MNI_0663 is not used during training (only during final testing in Phase 3)

# %% [markdown]
# Create an instance for the nine U-Nets

# %%
unets = un.MRA_UNets(app._model_path,
                    app._no_slices,
                    app._img_height,
                    app._img_width,
                    app.NO_PROJECTIONS,
                    app._unet_threshold)


# store the results of each training run in a dictionary for printing and further analysis 
results = dict()

# %% [markdown]
# The following process completes training for each of the nine projections in 10 - 15min on commodity hardware (MacBook Air, 8GB RAM). On this hardware, the entire training process completes in 2hours 30min. No GPU accelerations have been utilised.
#
# Important note: if you plan to start a clean new run, you should remove all the weightings for the neural networks in the 'models' folder. Otherwise, the process will run the weightings from the previous run and attempt to improve the model from there.

# %%
for i in range(app.NO_PROJECTIONS):  
    projection = str(i+1)
    print('********************************************')
    print('TRAINING NEURAL NETWORK FOR PROJECTION '+projection+'...')
    print('********************************************')
    # get padded image dimensions that should be used in neural network 
    h, w = unets.get_image_projection_size (projection)
 
    # Load the training data 
    src_trn[i] = np.zeros((len(mra_trn), h, w, 1), dtype=np.float32) 
    gt_trn[i]  = np.zeros((len(mra_trn), h, w, 1), dtype=np.float32) 
    j=0
    for f in mra_trn: 
        img = cv2.imread(app._debug_path + f +'/Step2 2D-Source-Projection-' + projection + '-CLAHE.jpg')
        ho, wo = unets.get_image_size (projection)
        x_img = sup.convert_image_to_grey(img,ho,wo)
        src_trn[j,:ho,:wo,0] = x_img / 255.0
        
        img = cv2.imread(app._debug_path + f +'/Step2 2D-GT-Projection-' + projection + '.jpg')
        ho, wo = unets.get_image_size (projection)
        x_img = sup.convert_image_to_grey(img,ho,wo)
        gt_trn[i,j,:ho,:wo,0] = x_img / 255.0
        j = j+1

    # Load the validation data 
    src_val = np.zeros((len(mra_val), h, w, 1), dtype=np.float32) 
    gt_val  = np.zeros((len(mra_val), h, w, 1), dtype=np.float32) 
    j=0
    for f in mra_val: 
        img = cv2.imread(app._debug_path + f +'/Step2 2D-Source-Projection-' + projection + '-CLAHE.jpg')
        ho, wo = unets.get_image_size (projection)
        x_img = sup.convert_image_to_grey(img,ho,wo)
        src_val[j,:ho,:wo,0] = x_img / 255.0
        
        img = cv2.imread(app._debug_path + f +'/Step2 2D-GT-Projection-' + projection + '.jpg')
        ho, wo = unets.get_image_size (projection)
        x_img = sup.convert_image_to_grey(img,ho,wo)
        gt_val[j,:ho,:wo,0] = x_img / 255.0
        j = j+1

    # initialise the U-Net for the p-th projection before starting the training run 
    model = unets.load_model(projection)
    model_par_file = app._model_path+'model-Projection-'+projection 
    # model.summary() if you want to display the summary of the UNET model 
    callbacks = [EarlyStopping(patience=10, verbose=1),
         ModelCheckpoint(model_par_file, verbose=1, save_best_only=True, save_weights_only=True)]
    # now start the training process for the p-th projection: 
    results[projection] = model.fit(src_trn, gt_trn, batch_size=1, epochs=50, callbacks=callbacks,
                    validation_data=(src_val, gt_val))
# Out:
# ********************************************
# TRAINING NEURAL NETWORK FOR PROJECTION 1...
# ********************************************
# Train on 1 samples, validate on 1 samples
# Epoch 1/20
# 1/1 [==============================] - 7s 7s/step - loss: 0.3773 - binary_accuracy: 0.8646 - val_loss: 0.3701 - val_binary_accuracy: 0.8531
#
# Epoch 00001: val_loss improved from inf to 0.37009, saving model to data/models/model-Projection-1
# Epoch 2/20
# 1/1 [==============================] - 2s 2s/step - loss: 0.3585 - binary_accuracy: 0.8772 - val_loss: 1.0311 - val_binary_accuracy: 0.6663
#
# Epoch 00002: val_loss did not improve from 0.37009
# Epoch 3/20
# 1/1 [==============================] - 2s 2s/step - loss: 0.3444 - binary_accuracy: 0.8812 - val_loss: 0.4222 - val_binary_accuracy: 0.8150
#
# Epoch 00003: val_loss did not improve from 0.37009
# Epoch 4/20
# 1/1 [==============================] - 2s 2s/step - loss: 0.3266 - binary_accuracy: 0.8917 - val_loss: 0.3287 - val_binary_accuracy: 0.8652
#
# Epoch 00004: val_loss improved from 0.37009 to 0.32868, saving model to data/models/model-Projection-1
# Epoch 5/20
# 1/1 [==============================] - 2s 2s/step - loss: 0.3144 - binary_accuracy: 0.8971 - val_loss: 0.3807 - val_binary_accuracy: 0.8421
#
# Epoch 00005: val_loss did not improve from 0.32868
# Epoch 6/20
# 1/1 [==============================] - 2s 2s/step - loss: 0.3021 - binary_accuracy: 0.8974 - val_loss: 0.4394 - val_binary_accuracy: 0.8094
#
# Epoch 00006: val_loss did not improve from 0.32868
# Epoch 7/20
# 1/1 [==============================] - 2s 2s/step - loss: 0.2921 - binary_accuracy: 0.8973 - val_loss: 0.3432 - val_binary_accuracy: 0.8393
#
# Epoch 00007: val_loss did not improve from 0.32868
# Epoch 8/20
# 1/1 [==============================] - 2s 2s/step - loss: 0.2840 - binary_accuracy: 0.8986 - val_loss: 0.2890 - val_binary_accuracy: 0.8633
#
# Epoch 00008: val_loss improved from 0.32868 to 0.28900, saving model to data/models/model-Projection-1
# Epoch 9/20
# 1/1 [==============================] - 2s 2s/step - loss: 0.2754 - binary_accuracy: 0.9020 - val_loss: 0.3103 - val_binary_accuracy: 0.8586
#
# Epoch 00009: val_loss did not improve from 0.28900
# Epoch 10/20
# 1/1 [==============================] - 2s 2s/step - loss: 0.2682 - binary_accuracy: 0.9029 - val_loss: 0.3665 - val_binary_accuracy: 0.8418
#
# Epoch 00010: val_loss did not improve from 0.28900
# Epoch 11/20
# 1/1 [==============================] - 2s 2s/step - loss: 0.2620 - binary_accuracy: 0.9030 - val_loss: 0.4032 - val_binary_accuracy: 0.8270
#
# Epoch 00011: val_loss did not improve from 0.28900
# Epoch 12/20
# 1/1 [==============================] - 2s 2s/step - loss: 0.2554 - binary_accuracy: 0.9036 - val_loss: 0.3820 - val_binary_accuracy: 0.8276
#
# Epoch 00012: val_loss did not improve from 0.28900
# Epoch 13/20
# 1/1 [==============================] - 2s 2s/step - loss: 0.2509 - binary_accuracy: 0.9046 - val_loss: 0.3822 - val_binary_accuracy: 0.8354
#
# Epoch 00013: val_loss did not improve from 0.28900
# Epoch 14/20
# 1/1 [==============================] - 2s 2s/step - loss: 0.2457 - binary_accuracy: 0.9056 - val_loss: 0.3100 - val_binary_accuracy: 0.8571
#
# Epoch 00014: val_loss did not improve from 0.28900
# Epoch 15/20
# 1/1 [==============================] - 2s 2s/step - loss: 0.2413 - binary_accuracy: 0.9064 - val_loss: 0.3071 - val_binary_accuracy: 0.8554
#
# Epoch 00015: val_loss did not improve from 0.28900
# Epoch 16/20
# 1/1 [==============================] - 3s 3s/step - loss: 0.2370 - binary_accuracy: 0.9066 - val_loss: 0.2728 - val_binary_accuracy: 0.8613
#
# Epoch 00016: val_loss improved from 0.28900 to 0.27278, saving model to data/models/model-Projection-1
# Epoch 17/20
# 1/1 [==============================] - 3s 3s/step - loss: 0.2324 - binary_accuracy: 0.9074 - val_loss: 0.2560 - val_binary_accuracy: 0.8667
#
# Epoch 00017: val_loss improved from 0.27278 to 0.25597, saving model to data/models/model-Projection-1
# Epoch 18/20
# 1/1 [==============================] - 2s 2s/step - loss: 0.2288 - binary_accuracy: 0.9076 - val_loss: 0.2989 - val_binary_accuracy: 0.8584
#
# Epoch 00018: val_loss did not improve from 0.25597
# Epoch 19/20
# 1/1 [==============================] - 2s 2s/step - loss: 0.2259 - binary_accuracy: 0.9078 - val_loss: 0.3036 - val_binary_accuracy: 0.8567
#
# Epoch 00019: val_loss did not improve from 0.25597
# Epoch 20/20
# 1/1 [==============================] - 2s 2s/step - loss: 0.2225 - binary_accuracy: 0.9083 - val_loss: 0.2710 - val_binary_accuracy: 0.8642
#
# Epoch 00020: val_loss did not improve from 0.25597
# ********************************************
# TRAINING NEURAL NETWORK FOR PROJECTION 2...
# ********************************************
# Train on 1 samples, validate on 1 samples
# Epoch 1/20
# 1/1 [==============================] - 9s 9s/step - loss: 0.7011 - binary_accuracy: 0.4674 - val_loss: 0.6595 - val_binary_accuracy: 0.5416
#
# Epoch 00001: val_loss improved from inf to 0.65946, saving model to data/models/model-Projection-2
# Epoch 2/20
# 1/1 [==============================] - 2s 2s/step - loss: 0.6565 - binary_accuracy: 0.5629 - val_loss: 0.6435 - val_binary_accuracy: 0.5702
#
# Epoch 00002: val_loss improved from 0.65946 to 0.64348, saving model to data/models/model-Projection-2
# Epoch 3/20
# 1/1 [==============================] - 2s 2s/step - loss: 0.6286 - binary_accuracy: 0.6128 - val_loss: 0.6514 - val_binary_accuracy: 0.5654
#
# Epoch 00003: val_loss did not improve from 0.64348
# Epoch 4/20
# 1/1 [==============================] - 2s 2s/step - loss: 0.6089 - binary_accuracy: 0.6326 - val_loss: 0.6944 - val_binary_accuracy: 0.5515
#
# Epoch 00004: val_loss did not improve from 0.64348
# Epoch 5/20
# 1/1 [==============================] - 2s 2s/step - loss: 0.5910 - binary_accuracy: 0.6532 - val_loss: 0.7752 - val_binary_accuracy: 0.5401
#
# Epoch 00005: val_loss did not improve from 0.64348
# Epoch 6/20
# 1/1 [==============================] - 2s 2s/step - loss: 0.5748 - binary_accuracy: 0.6763 - val_loss: 0.8920 - val_binary_accuracy: 0.5302
#
# Epoch 00006: val_loss did not improve from 0.64348
# Epoch 7/20
# 1/1 [==============================] - 2s 2s/step - loss: 0.5579 - binary_accuracy: 0.6996 - val_loss: 1.0393 - val_binary_accuracy: 0.5208
#
# Epoch 00007: val_loss did not improve from 0.64348
# Epoch 8/20
# 1/1 [==============================] - 2s 2s/step - loss: 0.5418 - binary_accuracy: 0.7200 - val_loss: 1.2309 - val_binary_accuracy: 0.5100
#
# Epoch 00008: val_loss did not improve from 0.64348
# Epoch 9/20
# 1/1 [==============================] - 2s 2s/step - loss: 0.5257 - binary_accuracy: 0.7384 - val_loss: 1.5075 - val_binary_accuracy: 0.4946
#
# Epoch 00009: val_loss did not improve from 0.64348
# Epoch 10/20
# 1/1 [==============================] - 2s 2s/step - loss: 0.5092 - binary_accuracy: 0.7548 - val_loss: 1.8805 - val_binary_accuracy: 0.4770
#
# Epoch 00010: val_loss did not improve from 0.64348
# Epoch 11/20
# 1/1 [==============================] - 2s 2s/step - loss: 0.4915 - binary_accuracy: 0.7726 - val_loss: 2.2861 - val_binary_accuracy: 0.4567
#
# Epoch 00011: val_loss did not improve from 0.64348
# Epoch 12/20
# 1/1 [==============================] - 2s 2s/step - loss: 0.4748 - binary_accuracy: 0.7876 - val_loss: 3.0142 - val_binary_accuracy: 0.4049
#
# Epoch 00012: val_loss did not improve from 0.64348
# Epoch 00012: early stopping
# ********************************************
# TRAINING NEURAL NETWORK FOR PROJECTION 3...
# ********************************************
# Train on 1 samples, validate on 1 samples
# Epoch 1/20
# 1/1 [==============================] - 11s 11s/step - loss: 0.6034 - binary_accuracy: 0.6454 - val_loss: 0.5641 - val_binary_accuracy: 0.6646
#
# Epoch 00001: val_loss improved from inf to 0.56410, saving model to data/models/model-Projection-3
# Epoch 2/20
# 1/1 [==============================] - 2s 2s/step - loss: 0.5270 - binary_accuracy: 0.7103 - val_loss: 0.5147 - val_binary_accuracy: 0.6899
#
# Epoch 00002: val_loss improved from 0.56410 to 0.51467, saving model to data/models/model-Projection-3
# Epoch 3/20
# 1/1 [==============================] - 2s 2s/step - loss: 0.4821 - binary_accuracy: 0.7370 - val_loss: 0.5001 - val_binary_accuracy: 0.6992
#
# Epoch 00003: val_loss improved from 0.51467 to 0.50014, saving model to data/models/model-Projection-3
# Epoch 4/20
# 1/1 [==============================] - 2s 2s/step - loss: 0.4542 - binary_accuracy: 0.7520 - val_loss: 0.5039 - val_binary_accuracy: 0.7040
#
# Epoch 00004: val_loss did not improve from 0.50014
# Epoch 5/20
# 1/1 [==============================] - 2s 2s/step - loss: 0.4329 - binary_accuracy: 0.7643 - val_loss: 0.5291 - val_binary_accuracy: 0.6972
#
# Epoch 00005: val_loss did not improve from 0.50014
# Epoch 6/20
# 1/1 [==============================] - 2s 2s/step - loss: 0.4163 - binary_accuracy: 0.7774 - val_loss: 0.5773 - val_binary_accuracy: 0.6815
#
# Epoch 00006: val_loss did not improve from 0.50014
# Epoch 7/20
# 1/1 [==============================] - 2s 2s/step - loss: 0.4022 - binary_accuracy: 0.7880 - val_loss: 0.6705 - val_binary_accuracy: 0.6476
#
# Epoch 00007: val_loss did not improve from 0.50014
# Epoch 8/20
# 1/1 [==============================] - 2s 2s/step - loss: 0.3876 - binary_accuracy: 0.7985 - val_loss: 0.8604 - val_binary_accuracy: 0.5732
#
# Epoch 00008: val_loss did not improve from 0.50014
# Epoch 9/20
# 1/1 [==============================] - 2s 2s/step - loss: 0.3729 - binary_accuracy: 0.8073 - val_loss: 1.2406 - val_binary_accuracy: 0.4693
#
# Epoch 00009: val_loss did not improve from 0.50014
# Epoch 10/20
# 1/1 [==============================] - 2s 2s/step - loss: 0.3582 - binary_accuracy: 0.8159 - val_loss: 1.9144 - val_binary_accuracy: 0.3839
#
# Epoch 00010: val_loss did not improve from 0.50014
# Epoch 11/20
# 1/1 [==============================] - 2s 2s/step - loss: 0.3442 - binary_accuracy: 0.8244 - val_loss: 2.6385 - val_binary_accuracy: 0.3351
#
# Epoch 00011: val_loss did not improve from 0.50014
# Epoch 12/20
# 1/1 [==============================] - 2s 2s/step - loss: 0.3311 - binary_accuracy: 0.8324 - val_loss: 3.1951 - val_binary_accuracy: 0.3315
#
# Epoch 00012: val_loss did not improve from 0.50014
# Epoch 13/20
# 1/1 [==============================] - 2s 2s/step - loss: 0.3185 - binary_accuracy: 0.8400 - val_loss: 3.3042 - val_binary_accuracy: 0.3307
#
# Epoch 00013: val_loss did not improve from 0.50014
# Epoch 00013: early stopping
# ********************************************
# TRAINING NEURAL NETWORK FOR PROJECTION 4...
# ********************************************
# Train on 1 samples, validate on 1 samples
# Epoch 1/20
# 1/1 [==============================] - 10s 10s/step - loss: 0.6520 - binary_accuracy: 0.5954 - val_loss: 0.6256 - val_binary_accuracy: 0.6447
#
# Epoch 00001: val_loss improved from inf to 0.62562, saving model to data/models/model-Projection-4
# Epoch 2/20
# 1/1 [==============================] - 3s 3s/step - loss: 0.6159 - binary_accuracy: 0.6713 - val_loss: 0.6017 - val_binary_accuracy: 0.6843
#
# Epoch 00002: val_loss improved from 0.62562 to 0.60171, saving model to data/models/model-Projection-4
# Epoch 3/20
# 1/1 [==============================] - 3s 3s/step - loss: 0.5902 - binary_accuracy: 0.7113 - val_loss: 0.6027 - val_binary_accuracy: 0.6923
#
# Epoch 00003: val_loss did not improve from 0.60171
# Epoch 4/20
# 1/1 [==============================] - 4s 4s/step - loss: 0.5659 - binary_accuracy: 0.7377 - val_loss: 0.6321 - val_binary_accuracy: 0.6948
#
# Epoch 00004: val_loss did not improve from 0.60171
# Epoch 5/20
# 1/1 [==============================] - 4s 4s/step - loss: 0.5418 - binary_accuracy: 0.7587 - val_loss: 0.7033 - val_binary_accuracy: 0.6958
#
# Epoch 00005: val_loss did not improve from 0.60171
# Epoch 6/20
# 1/1 [==============================] - 4s 4s/step - loss: 0.5187 - binary_accuracy: 0.7792 - val_loss: 0.8386 - val_binary_accuracy: 0.6967
#
# Epoch 00006: val_loss did not improve from 0.60171
# Epoch 7/20
# 1/1 [==============================] - 4s 4s/step - loss: 0.4958 - binary_accuracy: 0.7992 - val_loss: 1.0852 - val_binary_accuracy: 0.6915
#
# Epoch 00007: val_loss did not improve from 0.60171
# Epoch 8/20
# 1/1 [==============================] - 3s 3s/step - loss: 0.4730 - binary_accuracy: 0.8177 - val_loss: 1.4590 - val_binary_accuracy: 0.6815
#
# Epoch 00008: val_loss did not improve from 0.60171
# Epoch 9/20
# 1/1 [==============================] - 3s 3s/step - loss: 0.4514 - binary_accuracy: 0.8362 - val_loss: 1.7413 - val_binary_accuracy: 0.6787
#
# Epoch 00009: val_loss did not improve from 0.60171
# Epoch 10/20
# 1/1 [==============================] - 3s 3s/step - loss: 0.4318 - binary_accuracy: 0.8528 - val_loss: 1.7546 - val_binary_accuracy: 0.6852
#
# Epoch 00010: val_loss did not improve from 0.60171
# Epoch 11/20
# 1/1 [==============================] - 3s 3s/step - loss: 0.4138 - binary_accuracy: 0.8661 - val_loss: 1.7517 - val_binary_accuracy: 0.6882
#
# Epoch 00011: val_loss did not improve from 0.60171
# Epoch 12/20
# 1/1 [==============================] - 3s 3s/step - loss: 0.3976 - binary_accuracy: 0.8758 - val_loss: 1.9536 - val_binary_accuracy: 0.6720
#
# Epoch 00012: val_loss did not improve from 0.60171
# Epoch 00012: early stopping
# ********************************************
# TRAINING NEURAL NETWORK FOR PROJECTION 5...
# ********************************************
# Train on 1 samples, validate on 1 samples
# Epoch 1/20
# 1/1 [==============================] - 11s 11s/step - loss: 0.9735 - binary_accuracy: 0.3612 - val_loss: 0.9381 - val_binary_accuracy: 0.4416
#
# Epoch 00001: val_loss improved from inf to 0.93811, saving model to data/models/model-Projection-5
# Epoch 2/20
# 1/1 [==============================] - 3s 3s/step - loss: 0.8973 - binary_accuracy: 0.4448 - val_loss: 0.9974 - val_binary_accuracy: 0.4628
#
# Epoch 00002: val_loss did not improve from 0.93811
# Epoch 3/20
# 1/1 [==============================] - 3s 3s/step - loss: 0.8410 - binary_accuracy: 0.5011 - val_loss: 1.2103 - val_binary_accuracy: 0.4585
#
# Epoch 00003: val_loss did not improve from 0.93811
# Epoch 4/20
# 1/1 [==============================] - 3s 3s/step - loss: 0.7945 - binary_accuracy: 0.5487 - val_loss: 1.5885 - val_binary_accuracy: 0.4567
#
# Epoch 00004: val_loss did not improve from 0.93811
# Epoch 5/20
# 1/1 [==============================] - 3s 3s/step - loss: 0.7549 - binary_accuracy: 0.5967 - val_loss: 2.2991 - val_binary_accuracy: 0.4493
#
# Epoch 00005: val_loss did not improve from 0.93811
# Epoch 6/20
# 1/1 [==============================] - 4s 4s/step - loss: 0.7144 - binary_accuracy: 0.6452 - val_loss: 3.0943 - val_binary_accuracy: 0.4245
#
# Epoch 00006: val_loss did not improve from 0.93811
# Epoch 7/20
# 1/1 [==============================] - 4s 4s/step - loss: 0.6716 - binary_accuracy: 0.6955 - val_loss: 3.6405 - val_binary_accuracy: 0.3391
#
# Epoch 00007: val_loss did not improve from 0.93811
# Epoch 8/20
# 1/1 [==============================] - 4s 4s/step - loss: 0.6259 - binary_accuracy: 0.7412 - val_loss: 3.5333 - val_binary_accuracy: 0.2246
#
# Epoch 00008: val_loss did not improve from 0.93811
# Epoch 9/20
# 1/1 [==============================] - 4s 4s/step - loss: 0.5800 - binary_accuracy: 0.7803 - val_loss: 3.3799 - val_binary_accuracy: 0.2447
#
# Epoch 00009: val_loss did not improve from 0.93811
# Epoch 10/20
# 1/1 [==============================] - 4s 4s/step - loss: 0.5359 - binary_accuracy: 0.8129 - val_loss: 3.7300 - val_binary_accuracy: 0.2899
#
# Epoch 00010: val_loss did not improve from 0.93811
# Epoch 11/20
# 1/1 [==============================] - 4s 4s/step - loss: 0.5122 - binary_accuracy: 0.8155 - val_loss: 3.8236 - val_binary_accuracy: 0.2237
#
# Epoch 00011: val_loss did not improve from 0.93811
# Epoch 00011: early stopping
# ********************************************
# TRAINING NEURAL NETWORK FOR PROJECTION 6...
# ********************************************
# Train on 1 samples, validate on 1 samples
# Epoch 1/20
# 1/1 [==============================] - 14s 14s/step - loss: 0.8704 - binary_accuracy: 0.3548 - val_loss: 0.8715 - val_binary_accuracy: 0.4426
#
# Epoch 00001: val_loss improved from inf to 0.87150, saving model to data/models/model-Projection-6
# Epoch 2/20
# 1/1 [==============================] - 4s 4s/step - loss: 0.7897 - binary_accuracy: 0.4748 - val_loss: 1.1755 - val_binary_accuracy: 0.4913
#
# Epoch 00002: val_loss did not improve from 0.87150
# Epoch 3/20
# 1/1 [==============================] - 4s 4s/step - loss: 0.7287 - binary_accuracy: 0.5907 - val_loss: 2.0953 - val_binary_accuracy: 0.5165
#
# Epoch 00003: val_loss did not improve from 0.87150
# Epoch 4/20
# 1/1 [==============================] - 3s 3s/step - loss: 0.6828 - binary_accuracy: 0.6763 - val_loss: 2.9492 - val_binary_accuracy: 0.5286
# Epoch 00004: val_loss did not improve from 0.87150
# Epoch 5/20
# 1/1 [==============================] - 3s 3s/step - loss: 0.6469 - binary_accuracy: 0.7247 - val_loss: 3.5288 - val_binary_accuracy: 0.5346
#
# Epoch 00005: val_loss did not improve from 0.87150
# Epoch 6/20
# 1/1 [==============================] - 3s 3s/step - loss: 0.6168 - binary_accuracy: 0.7543 - val_loss: 3.3428 - val_binary_accuracy: 0.5473
#
# Epoch 00006: val_loss did not improve from 0.87150
# Epoch 7/20
# 1/1 [==============================] - 3s 3s/step - loss: 0.5897 - binary_accuracy: 0.7754 - val_loss: 2.5363 - val_binary_accuracy: 0.4191
#
# Epoch 00007: val_loss did not improve from 0.87150
# Epoch 8/20
# 1/1 [==============================] - 4s 4s/step - loss: 0.5637 - binary_accuracy: 0.7907 - val_loss: 2.6069 - val_binary_accuracy: 0.2726
#
# Epoch 00008: val_loss did not improve from 0.87150
# Epoch 9/20
# 1/1 [==============================] - 4s 4s/step - loss: 0.5380 - binary_accuracy: 0.8066 - val_loss: 3.4675 - val_binary_accuracy: 0.2616
#
# Epoch 00009: val_loss did not improve from 0.87150
# Epoch 10/20
# 1/1 [==============================] - 4s 4s/step - loss: 0.5150 - binary_accuracy: 0.8220 - val_loss: 4.8362 - val_binary_accuracy: 0.2486
#
# Epoch 00010: val_loss did not improve from 0.87150
# Epoch 11/20
# 1/1 [==============================] - 4s 4s/step - loss: 0.4912 - binary_accuracy: 0.8357 - val_loss: 6.5980 - val_binary_accuracy: 0.2196
#
# Epoch 00011: val_loss did not improve from 0.87150
# Epoch 00011: early stopping
# ********************************************
# TRAINING NEURAL NETWORK FOR PROJECTION 7...
# ********************************************
# Train on 1 samples, validate on 1 samples
# Epoch 1/20
# 1/1 [==============================] - 12s 12s/step - loss: 0.7648 - binary_accuracy: 0.4564 - val_loss: 0.7032 - val_binary_accuracy: 0.5742
#
# Epoch 00001: val_loss improved from inf to 0.70318, saving model to data/models/model-Projection-7
# Epoch 2/20
# 1/1 [==============================] - 4s 4s/step - loss: 0.7122 - binary_accuracy: 0.5801 - val_loss: 0.6744 - val_binary_accuracy: 0.6208
#
# Epoch 00002: val_loss improved from 0.70318 to 0.67437, saving model to data/models/model-Projection-7
# Epoch 3/20
# 1/1 [==============================] - 4s 4s/step - loss: 0.6737 - binary_accuracy: 0.6245 - val_loss: 0.6638 - val_binary_accuracy: 0.6485
#
# Epoch 00003: val_loss improved from 0.67437 to 0.66377, saving model to data/models/model-Projection-7
# Epoch 4/20
# 1/1 [==============================] - 4s 4s/step - loss: 0.6395 - binary_accuracy: 0.6582 - val_loss: 0.6895 - val_binary_accuracy: 0.6625
#
# Epoch 00004: val_loss did not improve from 0.66377
# Epoch 5/20
# 1/1 [==============================] - 3s 3s/step - loss: 0.6070 - binary_accuracy: 0.7008 - val_loss: 0.7523 - val_binary_accuracy: 0.6739
#
# Epoch 00005: val_loss did not improve from 0.66377
# Epoch 6/20
# 1/1 [==============================] - 4s 4s/step - loss: 0.5760 - binary_accuracy: 0.7434 - val_loss: 0.8754 - val_binary_accuracy: 0.6740
#
# Epoch 00006: val_loss did not improve from 0.66377
# Epoch 7/20
# 1/1 [==============================] - 3s 3s/step - loss: 0.5488 - binary_accuracy: 0.7732 - val_loss: 1.1390 - val_binary_accuracy: 0.6568
#
# Epoch 00007: val_loss did not improve from 0.66377
# Epoch 8/20
# 1/1 [==============================] - 3s 3s/step - loss: 0.5247 - binary_accuracy: 0.7968 - val_loss: 1.6310 - val_binary_accuracy: 0.6234
#
# Epoch 00008: val_loss did not improve from 0.66377
# Epoch 9/20
# 1/1 [==============================] - 3s 3s/step - loss: 0.5016 - binary_accuracy: 0.8184 - val_loss: 2.4881 - val_binary_accuracy: 0.5738
#
# Epoch 00009: val_loss did not improve from 0.66377
# Epoch 10/20
# 1/1 [==============================] - 4s 4s/step - loss: 0.4782 - binary_accuracy: 0.8381 - val_loss: 3.7389 - val_binary_accuracy: 0.5126
#
# Epoch 00010: val_loss did not improve from 0.66377
# Epoch 11/20
# 1/1 [==============================] - 4s 4s/step - loss: 0.4534 - binary_accuracy: 0.8551 - val_loss: 5.1602 - val_binary_accuracy: 0.4553
#
# Epoch 00011: val_loss did not improve from 0.66377
# Epoch 12/20
# 1/1 [==============================] - 4s 4s/step - loss: 0.4301 - binary_accuracy: 0.8680 - val_loss: 5.1797 - val_binary_accuracy: 0.4052
#
# Epoch 00012: val_loss did not improve from 0.66377
# Epoch 13/20
# 1/1 [==============================] - 4s 4s/step - loss: 0.4065 - binary_accuracy: 0.8787 - val_loss: 3.7176 - val_binary_accuracy: 0.4439
#
# Epoch 00013: val_loss did not improve from 0.66377
# Epoch 00013: early stopping
# ********************************************
# TRAINING NEURAL NETWORK FOR PROJECTION 8...
# ********************************************
# Train on 1 samples, validate on 1 samples
# Epoch 1/20
# 1/1 [==============================] - 13s 13s/step - loss: 0.4663 - binary_accuracy: 0.8588 - val_loss: 0.4678 - val_binary_accuracy: 0.8218
#
# Epoch 00001: val_loss improved from inf to 0.46783, saving model to data/models/model-Projection-8
# Epoch 2/20
# 1/1 [==============================] - 4s 4s/step - loss: 0.4196 - binary_accuracy: 0.8637 - val_loss: 0.4449 - val_binary_accuracy: 0.8056
#
# Epoch 00002: val_loss improved from 0.46783 to 0.44486, saving model to data/models/model-Projection-8
# Epoch 3/20
# 1/1 [==============================] - 3s 3s/step - loss: 0.3932 - binary_accuracy: 0.8594 - val_loss: 0.4303 - val_binary_accuracy: 0.8007
#
# Epoch 00003: val_loss improved from 0.44486 to 0.43026, saving model to data/models/model-Projection-8
# Epoch 4/20
# 1/1 [==============================] - 3s 3s/step - loss: 0.3760 - binary_accuracy: 0.8643 - val_loss: 0.4118 - val_binary_accuracy: 0.8048
#
# Epoch 00004: val_loss improved from 0.43026 to 0.41179, saving model to data/models/model-Projection-8
# Epoch 5/20
# 1/1 [==============================] - 3s 3s/step - loss: 0.3612 - binary_accuracy: 0.8706 - val_loss: 0.3888 - val_binary_accuracy: 0.8174
#
# Epoch 00005: val_loss improved from 0.41179 to 0.38881, saving model to data/models/model-Projection-8
# Epoch 6/20
# 1/1 [==============================] - 3s 3s/step - loss: 0.3482 - binary_accuracy: 0.8784 - val_loss: 0.3584 - val_binary_accuracy: 0.8349
#
# Epoch 00006: val_loss improved from 0.38881 to 0.35843, saving model to data/models/model-Projection-8
# Epoch 7/20
# 1/1 [==============================] - 3s 3s/step - loss: 0.3353 - binary_accuracy: 0.8871 - val_loss: 0.3252 - val_binary_accuracy: 0.8542
#
# Epoch 00007: val_loss improved from 0.35843 to 0.32517, saving model to data/models/model-Projection-8
# Epoch 8/20
# 1/1 [==============================] - 4s 4s/step - loss: 0.3238 - binary_accuracy: 0.8954 - val_loss: 0.2974 - val_binary_accuracy: 0.8682
#
# Epoch 00008: val_loss improved from 0.32517 to 0.29736, saving model to data/models/model-Projection-8
# Epoch 9/20
# 1/1 [==============================] - 4s 4s/step - loss: 0.3128 - binary_accuracy: 0.9035 - val_loss: 0.2839 - val_binary_accuracy: 0.8727
#
# Epoch 00009: val_loss improved from 0.29736 to 0.28395, saving model to data/models/model-Projection-8
# Epoch 10/20
# 1/1 [==============================] - 4s 4s/step - loss: 0.3029 - binary_accuracy: 0.9088 - val_loss: 0.2856 - val_binary_accuracy: 0.8696
#
# Epoch 00010: val_loss did not improve from 0.28395
# Epoch 11/20
# 1/1 [==============================] - 4s 4s/step - loss: 0.2939 - binary_accuracy: 0.9133 - val_loss: 0.2945 - val_binary_accuracy: 0.8641
#
# Epoch 00011: val_loss did not improve from 0.28395
# Epoch 12/20
# 1/1 [==============================] - 3s 3s/step - loss: 0.2859 - binary_accuracy: 0.9162 - val_loss: 0.3080 - val_binary_accuracy: 0.8571
#
# Epoch 00012: val_loss did not improve from 0.28395
# Epoch 13/20
# 1/1 [==============================] - 4s 4s/step - loss: 0.2787 - binary_accuracy: 0.9186 - val_loss: 0.3297 - val_binary_accuracy: 0.8475
#
# Epoch 00013: val_loss did not improve from 0.28395
# Epoch 14/20
# 1/1 [==============================] - 4s 4s/step - loss: 0.2717 - binary_accuracy: 0.9213 - val_loss: 0.3891 - val_binary_accuracy: 0.8235
#
# Epoch 00014: val_loss did not improve from 0.28395
# Epoch 15/20
# 1/1 [==============================] - 4s 4s/step - loss: 0.2644 - binary_accuracy: 0.9218 - val_loss: 0.4891 - val_binary_accuracy: 0.7933
#
# Epoch 00015: val_loss did not improve from 0.28395
# Epoch 16/20
# 1/1 [==============================] - 4s 4s/step - loss: 0.2573 - binary_accuracy: 0.9225 - val_loss: 0.6082 - val_binary_accuracy: 0.7675
#
# Epoch 00016: val_loss did not improve from 0.28395
# Epoch 17/20
# 1/1 [==============================] - 4s 4s/step - loss: 0.2505 - binary_accuracy: 0.9233 - val_loss: 0.7250 - val_binary_accuracy: 0.7442
#
# Epoch 00017: val_loss did not improve from 0.28395
# Epoch 18/20
# 1/1 [==============================] - 4s 4s/step - loss: 0.2441 - binary_accuracy: 0.9247 - val_loss: 0.9051 - val_binary_accuracy: 0.7151
#
# Epoch 00018: val_loss did not improve from 0.28395
# Epoch 19/20
# 1/1 [==============================] - 4s 4s/step - loss: 0.2375 - binary_accuracy: 0.9261 - val_loss: 1.0478 - val_binary_accuracy: 0.6913
#
# Epoch 00019: val_loss did not improve from 0.28395
# Epoch 00019: early stopping
# ********************************************
# TRAINING NEURAL NETWORK FOR PROJECTION 9...
# ********************************************
# Train on 1 samples, validate on 1 samples
# Epoch 1/20
# 1/1 [==============================] - 14s 14s/step - loss: 0.6163 - binary_accuracy: 0.6459 - val_loss: 0.6128 - val_binary_accuracy: 0.6701
#
# Epoch 00001: val_loss improved from inf to 0.61285, saving model to data/models/model-Projection-9
# Epoch 2/20
# 1/1 [==============================] - 4s 4s/step - loss: 0.5776 - binary_accuracy: 0.6968 - val_loss: 0.6352 - val_binary_accuracy: 0.6792
#
# Epoch 00002: val_loss did not improve from 0.61285
# Epoch 3/20
# 1/1 [==============================] - 4s 4s/step - loss: 0.5482 - binary_accuracy: 0.7280 - val_loss: 0.6825 - val_binary_accuracy: 0.6715
#
# Epoch 00003: val_loss did not improve from 0.61285
# Epoch 4/20
# 1/1 [==============================] - 3s 3s/step - loss: 0.5249 - binary_accuracy: 0.7460 - val_loss: 0.7385 - val_binary_accuracy: 0.6592
#
# Epoch 00004: val_loss did not improve from 0.61285
# Epoch 5/20
# 1/1 [==============================] - 4s 4s/step - loss: 0.5018 - binary_accuracy: 0.7655 - val_loss: 0.7542 - val_binary_accuracy: 0.6612
#
# Epoch 00005: val_loss did not improve from 0.61285
# Epoch 6/20
# 1/1 [==============================] - 3s 3s/step - loss: 0.4786 - binary_accuracy: 0.7880 - val_loss: 0.7018 - val_binary_accuracy: 0.6923
#
# Epoch 00006: val_loss did not improve from 0.61285
# Epoch 7/20
# 1/1 [==============================] - 4s 4s/step - loss: 0.4565 - binary_accuracy: 0.8177 - val_loss: 0.6299 - val_binary_accuracy: 0.7292
#
# Epoch 00007: val_loss did not improve from 0.61285
# Epoch 8/20
# 1/1 [==============================] - 4s 4s/step - loss: 0.4346 - binary_accuracy: 0.8486 - val_loss: 0.6844 - val_binary_accuracy: 0.6749
#
# Epoch 00008: val_loss did not improve from 0.61285
# Epoch 9/20
# 1/1 [==============================] - 4s 4s/step - loss: 0.4136 - binary_accuracy: 0.8737 - val_loss: 1.0839 - val_binary_accuracy: 0.4804
#
# Epoch 00009: val_loss did not improve from 0.61285
# Epoch 10/20
# 1/1 [==============================] - 4s 4s/step - loss: 0.3940 - binary_accuracy: 0.8921 - val_loss: 1.4336 - val_binary_accuracy: 0.4214
#
# Epoch 00010: val_loss did not improve from 0.61285
# Epoch 11/20
# 1/1 [==============================] - 4s 4s/step - loss: 0.3786 - binary_accuracy: 0.9021 - val_loss: 1.0737 - val_binary_accuracy: 0.4904
#
# Epoch 00011: val_loss did not improve from 0.61285
# Epoch 00011: early stopping

# %% [markdown]
# Display results of learning curves for each of the nine projections

# %%
for i in range(app.NO_PROJECTIONS):
    projection = str(i+1)
    res = results[projection]
    plt.figure(figsize=(8, 8))
    plt.title("Learning Curve for Image Projection "+projection)
    plt.plot(res.history["loss"], label="Loss")
    plt.plot(res.history["val_loss"], label="Validation Loss")
    plt.plot( np.argmin(res.history["val_loss"]), np.min(res.history["val_loss"]), marker="x", color="r", label="Best Model")
    plt.xlabel("Epochs")
    plt.ylabel("Log Loss (Cross Entropy)")
    plt.legend();

# %% [markdown]
# Test accuracy of each projection against validation record

# %%
for i in range(app.NO_PROJECTIONS): 
    print('Evaluate performance of model against projection '+str(i+1))
    model = unets.load_model(str(i+1))
    #model.load_weights(app._model_path+'model-Projection-'+str(i+1))
    out = model.evaluate(src_val, gt_val, verbose=0)
    print(out)
# Out:
# Evaluate performance of model against projection 1
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-d0284762b4d5> in <module>()
#       3     model = unets.load_model(str(i+1))
#       4     #model.load_weights(app._model_path+'model-Projection-'+str(i+1))
# ----> 5     out = model.evaluate(src_val, gt_val, verbose=0)
#       6     print(out)
#
# ~/anaconda3/lib/python3.6/site-packages/keras/engine/training.py in evaluate(self, x, y, batch_size, verbose, sample_weight, steps)
#    1100             x, y,
#    1101             sample_weight=sample_weight,
# -> 1102             batch_size=batch_size)
#    1103         # Prepare inputs, delegate logic to `test_loop`.
#    1104         if self._uses_dynamic_learning_phase():
#
# ~/anaconda3/lib/python3.6/site-packages/keras/engine/training.py in _standardize_user_data(self, x, y, sample_weight, class_weight, check_array_lengths, batch_size)
#     749             feed_input_shapes,
#     750             check_batch_axis=False,  # Don't enforce the batch size.
# --> 751             exception_prefix='input')
#     752
#     753         if y is not None:
#
# ~/anaconda3/lib/python3.6/site-packages/keras/engine/training_utils.py in standardize_input_data(data, names, shapes, check_batch_axis, exception_prefix)
#     136                             ': expected ' + names[i] + ' to have shape ' +
#     137                             str(shape) + ' but got array with shape ' +
# --> 138                             str(data_shape))
#     139     return data
#     140
#
# ValueError: Error when checking input: expected img to have shape (320, 320, 1) but got array with shape (320, 576, 1)

# %% [markdown]
# Visualise source / ground truth image pair for training data

# %%
# Check if training data looks all right
ix = 0 # just work with the first record 
fig, ax = plt.subplots(1, 2, figsize=(20, 10))

ax[0].imshow(src_trn[ix, ..., 0], cmap='gray', interpolation='bilinear')
ax[0].set_title('Source Image')

ax[1].imshow(gt_trn[ix].squeeze(), interpolation='bilinear', cmap='gray')
ax[1].set_title('Ground Truth');

# %% [markdown]
# Visualise source / ground truth image pair for test data (validation data)

# %%
# Check if validation data looks all right
ix = 0 # just work with the first record 
fig, ax = plt.subplots(1, 2, figsize=(20, 10))

ax[0].imshow(src_val[ix, ..., 0], cmap='gray', interpolation='bilinear')
ax[0].set_title('Source Image')

ax[1].imshow(gt_val[ix].squeeze(), interpolation='bilinear', cmap='gray')
ax[1].set_title('Ground Truth');

# %%
# Load data for any of the nine UNET training runs for the image projections ('1' to '9')
projection = '9'
model.load_weights(app._model_path+'model-Projection-'+projection)

# %%
# Evaluate on validation set (this must be equals to the best log_loss)
model.evaluate(src_val, gt_val, verbose=1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-b1cfc750a61d> in <module>()
#       1 # Evaluate on validation set (this must be equals to the best log_loss)
# ----> 2 model.evaluate(src_val, gt_val, verbose=1)
#
# ~/anaconda3/lib/python3.6/site-packages/keras/engine/training.py in evaluate(self, x, y, batch_size, verbose, sample_weight, steps)
#    1100             x, y,
#    1101             sample_weight=sample_weight,
# -> 1102             batch_size=batch_size)
#    1103         # Prepare inputs, delegate logic to `test_loop`.
#    1104         if self._uses_dynamic_learning_phase():
#
# ~/anaconda3/lib/python3.6/site-packages/keras/engine/training.py in _standardize_user_data(self, x, y, sample_weight, class_weight, check_array_lengths, batch_size)
#     749             feed_input_shapes,
#     750             check_batch_axis=False,  # Don't enforce the batch size.
# --> 751             exception_prefix='input')
#     752
#     753         if y is not None:
#
# ~/anaconda3/lib/python3.6/site-packages/keras/engine/training_utils.py in standardize_input_data(data, names, shapes, check_batch_axis, exception_prefix)
#     136                             ': expected ' + names[i] + ' to have shape ' +
#     137                             str(shape) + ' but got array with shape ' +
# --> 138                             str(data_shape))
#     139     return data
#     140
#
# ValueError: Error when checking input: expected img to have shape (320, 320, 1) but got array with shape (320, 576, 1)

# %% [markdown]
# Run predictions on training and validation data

# %%
# Predict on train, val and test
preds_trn = model.predict(src_trn, verbose=1)
preds_val   = model.predict(src_val, verbose=1)

# Threshold predictions
preds_trn_t = (preds_trn > app._unet_threshold).astype(np.uint16)
preds_val_t = (preds_val > app._unet_threshold).astype(np.uint16)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-16-a5e9827df9fc> in <module>()
#       1 # Predict on train, val and test
# ----> 2 preds_trn = model.predict(src_trn, verbose=1)
#       3 preds_val   = model.predict(src_val, verbose=1)
#       4
#       5 # Threshold predictions
#
# ~/anaconda3/lib/python3.6/site-packages/keras/engine/training.py in predict(self, x, batch_size, verbose, steps)
#    1147                              'argument.')
#    1148         # Validate user data.
# -> 1149         x, _, _ = self._standardize_user_data(x)
#    1150         if self.stateful:
#    1151             if x[0].shape[0] > batch_size and x[0].shape[0] % batch_size != 0:
#
# ~/anaconda3/lib/python3.6/site-packages/keras/engine/training.py in _standardize_user_data(self, x, y, sample_weight, class_weight, check_array_lengths, batch_size)
#     749             feed_input_shapes,
#     750             check_batch_axis=False,  # Don't enforce the batch size.
# --> 751             exception_prefix='input')
#     752
#     753         if y is not None:
#
# ~/anaconda3/lib/python3.6/site-packages/keras/engine/training_utils.py in standardize_input_data(data, names, shapes, check_batch_axis, exception_prefix)
#     136                             ': expected ' + names[i] + ' to have shape ' +
#     137                             str(shape) + ' but got array with shape ' +
# --> 138                             str(data_shape))
#     139     return data
#     140
#
# ValueError: Error when checking input: expected img to have shape (320, 320, 1) but got array with shape (320, 576, 1)

# %% [markdown]
# Plot the predictions

# %%
def plot_sample(mra_id, X, y, binary_preds, ix):
    fig, ax = plt.subplots(1, 4, figsize=(20, 10))
    ax[0].imshow(X[ix, ..., 0], cmap='gray')
    ax[0].set_title('Source Image ('+mra_id+')')

    ax[1].imshow(y[ix].squeeze(), cmap='gray')
    ax[1].set_title('Ground Truth ('+mra_id+')')

    ax[2].imshow(binary_preds[ix].squeeze(), vmin=0, vmax=1, cmap='gray')
    ax[2].set_title('Binary Prediction ('+mra_id+')')
    
    ax[3].imshow(y[ix].squeeze()+binary_preds[ix].squeeze()*2, vmin=0, vmax=3, cmap='CMRmap', interpolation='nearest')
    ax[3].set_title('Binary Prediction & Ground Truth Overlay');

# %% [markdown]
# Compare the results for the training data

# %%
# Check if training data looks all right
for ix in range(len(mra_trn)):
    plot_sample(mra_trn[ix], src_trn, gt_trn, preds_trn_t, ix)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-793d3472e701> in <module>()
#       1 # Check if training data looks all right
#       2 for ix in range(len(mra_trn)):
# ----> 3     plot_sample(mra_trn[ix], src_trn, gt_trn, preds_trn_t, ix)
#
# NameError: name 'preds_trn_t' is not defined

# %% [markdown]
# Check if validation data looks all right (this is the data that has not been used for training)

# %%
# Check if validation data look all right 
for ix in range(len(mra_val)):
    plot_sample(mra_val[ix],src_val, gt_val, preds_val_t, ix)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-e3814de44c71> in <module>()
#       1 # Check if validation data look all right
#       2 for ix in range(len(mra_val)):
# ----> 3     plot_sample(mra_val[ix],src_val, gt_val, preds_val_t, ix)
#
# NameError: name 'preds_val_t' is not defined

# %% [markdown]
# ## Part B - Evaluating the Segmentation Results of the Image Projections
# Evaluation of the Results against Performance Metrics (this part can be executed against existing UNET models, without the need to train first the U-Nets from Part A

# %%
 
# Training data 
dim     = app._img_height+app._img_width+app._no_slices # be generous with the max size of 2D projection images
lngth   = len(mra_trn) + len(mra_val)
gt_trn   = np.zeros((app.NO_PROJECTIONS,lngth, dim, dim), dtype=int) 
pred_trn = np.zeros((app.NO_PROJECTIONS,lngth, dim, dim), dtype=int) 

for i in range(app.NO_PROJECTIONS):  
    projection = str(i+1)
    print('Projection '+projection)
    model = unets.load_model(projection)
    
    # get padded image dimensions that should be used in neural network 
    h, w = unets.get_image_projection_size (projection)

    j=0
    for f in (mra_trn + mra_val): 
        print('... '+f)
        # Load ground truth of image projection 
        img = cv2.imread(app._debug_path + f +'/Step2 2D-GT-Projection-' + projection + '.jpg')
        ho, wo = unets.get_image_size (projection)
        gt_img = sup.convert_image_to_grey(img,ho,wo)
        gt_img = (gt_img > app._gt_pxl_threshold)
        gt_img = gt_img.astype(int)
        gt_trn[i,j,:ho,:wo] = gt_img
        
        # calculate predicted map, based on unet configuration 
        img = cv2.imread(app._debug_path + f +'/Step2 2D-Source-Projection-' + projection + '-CLAHE.jpg')
        ho, wo = unets.get_image_size (projection)
        x_img = sup.convert_image_to_grey(img,ho,wo)
        x_img = x_img / 255.0
        src_nn = np.zeros((1, h, w, 1), dtype=np.float32) 
        src_nn [0,:ho,:wo,0] = x_img
        pred = model.predict(src_nn, verbose=0)
        pred = (pred > app._unet_threshold)
        pred = pred.squeeze()
        pred = pred.astype(int)
        pred_trn[i,j,:ho,:wo] = pred[:ho,:wo]
        j = j+1
# Out:
# Projection 1
# ... MNI_0657
# ... MNI_0592
# ... MNI_0643
# ... MNI_0664
# ... MNI_0590
# ... MNI_0591
# ... MNI_0640
# ... MNI_0648
# ... MNI_0656
# Projection 2
# ... MNI_0657
# ... MNI_0592
# ... MNI_0643
# ... MNI_0664
# ... MNI_0590
# ... MNI_0591
# ... MNI_0640
# ... MNI_0648
# ... MNI_0656
# Projection 3
# ... MNI_0657
# ... MNI_0592
# ... MNI_0643
# ... MNI_0664
# ... MNI_0590
# ... MNI_0591
# ... MNI_0640
# ... MNI_0648
# ... MNI_0656
# Projection 4
# ... MNI_0657
# ... MNI_0592
# ... MNI_0643
# ... MNI_0664
# ... MNI_0590
# ... MNI_0591
# ... MNI_0640
# ... MNI_0648
# ... MNI_0656
# Projection 5
# ... MNI_0657
# ... MNI_0592
# ... MNI_0643
# ... MNI_0664
# ... MNI_0590
# ... MNI_0591
# ... MNI_0640
# ... MNI_0648
# ... MNI_0656
# Projection 6
# ... MNI_0657
# ... MNI_0592
# ... MNI_0643
# ... MNI_0664
# ... MNI_0590
# ... MNI_0591
# ... MNI_0640
# ... MNI_0648
# ... MNI_0656
# Projection 7
# ... MNI_0657
# ... MNI_0592
# ... MNI_0643
# ... MNI_0664
# ... MNI_0590
# ... MNI_0591
# ... MNI_0640
# ... MNI_0648
# ... MNI_0656
# Projection 8
# ... MNI_0657
# ... MNI_0592
# ... MNI_0643
# ... MNI_0664
# ... MNI_0590
# ... MNI_0591
# ... MNI_0640
# ... MNI_0648
# ... MNI_0656
# Projection 9
# ... MNI_0657
# ... MNI_0592
# ... MNI_0643
# ... MNI_0664
# ... MNI_0590
# ... MNI_0591
# ... MNI_0640
# ... MNI_0648
# ... MNI_0656

# %% [markdown]
# Next we calculate the overall performance metrics

# %%
def calc_metrics (gt, pred, heading, short=True): 
    diff = gt - (pred *2)
    fn = (diff== 1).sum()
    tp = (diff==-1).sum()
    fp = (diff==-2).sum()
    tn = (diff== 0).sum()
    p  = tp / (tp + fp)  # precision 
    r  = tp / (tp + fn)  # recall 
    f1 = 2*p*r/(p+r)     # F1 score
    print(heading)
    if not short: 
        print('FN - Green  - (Blood vessel missed):                  ' + str(fn) )
        print('TP - Yellow - (Correctly classified as blood vessel): ' + str(tp) )
        print('FP - Red    - (Wrongly classified as blood vessel):   ' + str(fp) )
        print('TN - Opaque - (Correctly classified as background):   ' + str(tn) )
        print('***************************************************************')
        print('Total pixel number:                                   ' + str(fn+tp+fp+tn))
        print('    ')
    print('Precision:   ' + str(np.round(100*p,2))+'%')
    print('Recall:      ' + str(np.round(100*r,2))+'%')
    print('F1 Score:    ' + str(np.round(100*2*p*r/(p+r),2))+'%')
    print('    ')

# %%
calc_metrics(gt_trn,pred_trn,'Overall Performance across all training data')
# Out:
# Overall Performance across all training data
# Precision:   77.09%
# Recall:      73.97%
# F1 Score:    75.5%

# %%
for i in range(app.NO_PROJECTIONS):  
    calc_metrics(gt_trn[i,:,:,:],pred_trn[i,:,:,:],'Overall Performance across Projection '+str(i+1))
# Out:
# Overall Performance across Projection 1
# Precision:   75.64%
# Recall:      84.29%
# F1 Score:    79.73%
#
# Overall Performance across Projection 2
# Precision:   81.98%
# Recall:      94.54%
# F1 Score:    87.81%
#
# Overall Performance across Projection 3
# Precision:   79.57%
# Recall:      66.22%
# F1 Score:    72.28%
#
# Overall Performance across Projection 4
# Precision:   81.93%
# Recall:      61.91%
# F1 Score:    70.53%
#
# Overall Performance across Projection 5
# Precision:   70.55%
# Recall:      87.71%
# F1 Score:    78.2%
#
# Overall Performance across Projection 6
# Precision:   78.78%
# Recall:      63.88%
# F1 Score:    70.55%
#
# Overall Performance across Projection 7
# Precision:   78.78%
# Recall:      71.99%
# F1 Score:    75.23%
#
# Overall Performance across Projection 8
# Precision:   70.61%
# Recall:      86.21%
# F1 Score:    77.64%
#
# Overall Performance across Projection 9
# Precision:   84.29%
# Recall:      56.56%
# F1 Score:    67.7%

# %%
j=0
for f in mra_trn + mra_val: 
    calc_metrics(gt_trn[:,j,:,:],pred_trn[:,j,:,:],'Overall Performance across MRA scan '+f)
    j = j+1
# Out:
# Overall Performance across MRA scan MNI_0657
# Precision:   75.58%
# Recall:      77.73%
# F1 Score:    76.64%
#
# Overall Performance across MRA scan MNI_0592
# Precision:   76.67%
# Recall:      71.98%
# F1 Score:    74.25%
#
# Overall Performance across MRA scan MNI_0643
# Precision:   76.95%
# Recall:      77.39%
# F1 Score:    77.17%
#
# Overall Performance across MRA scan MNI_0664
# Precision:   76.25%
# Recall:      76.93%
# F1 Score:    76.59%
#
# Overall Performance across MRA scan MNI_0590
# Precision:   77.15%
# Recall:      64.84%
# F1 Score:    70.47%
#
# Overall Performance across MRA scan MNI_0591
# Precision:   77.3%
# Recall:      77.55%
# F1 Score:    77.42%
#
# Overall Performance across MRA scan MNI_0640
# Precision:   73.12%
# Recall:      77.11%
# F1 Score:    75.06%
#
# Overall Performance across MRA scan MNI_0648
# Precision:   76.99%
# Recall:      77.54%
# F1 Score:    77.27%
#
# Overall Performance across MRA scan MNI_0656
# Precision:   85.01%
# Recall:      64.92%
# F1 Score:    73.62%

# %% [markdown]
# Plot the results

# %%
def plot_sample(mra_id, gt, pred, proj):
    fig, ax = plt.subplots(1, 3, figsize=(20, 5))
    fig.suptitle('Projection '+ str(proj+1))
    
    # ground truth
    gt_rgb = np.zeros((350,600,3)) + 255
    gt_rgb[:,:,0] = -255*gt[:,:] + 255 # red component 
    gt_rgb[:,:,1] =  255               # green component 
    gt_rgb[:,:,2] = -255*gt[:,:] + 255 # blue component 
    
    # prediction
    pred_rgb = np.zeros((350,600,3)) + 255
    pred_rgb[:,:,0] =  255                  # red component 
    pred_rgb[:,:,1] = -255*pred[:,:] + 255  # green component 
    pred_rgb[:,:,2] = -255*pred[:,:] + 255  # blue component 
    
    # overlay 
    overlay = 2*gt - pred
    overlay_rgb = np.zeros((350,600,3)) + 255
    overlay_rgb[:,:,0] =  -255*(overlay == 2) + 255    # red component is from gr
    overlay_rgb[:,:,1] =  -255*(overlay == -1) + 255   # green component 
    overlay_rgb[:,:,2] =  255 - 255*(overlay != 0)     # blue component 
    
    ax[0].imshow(gt_rgb)
    ax[0].set_title('Ground Truth ('+mra_id+')')

    ax[1].imshow(pred_rgb)
    ax[1].set_title('UNet Prediction Map ('+mra_id+')')
    
    ax[2].imshow(overlay_rgb)
    ax[2].set_title('UNet Prediction Map with Ground Truth Overlay');

# %%
def plot_all(j):
    mra_id = mra_all[j]
    
    fig, ax = plt.subplots(app.NO_PROJECTIONS, 3, figsize=(20, 30))
    # fig.suptitle('UNet Segmentation Results for Record ' + mra_id, size=30)
    
    for i in range(app.NO_PROJECTIONS):
        projection = str(i+1)
        gt = gt_trn[i,j,:350,:600]
        pred = pred_trn[i,j,:350,:600]
    
        # ground truth
        gt_rgb = np.zeros((350,600,3)) + 255
        gt_rgb[:,:,0] = -255*gt[:,:] + 255 # red component 
        gt_rgb[:,:,1] =  255               # green component 
        gt_rgb[:,:,2] = -255*gt[:,:] + 255 # blue component 
    
        # prediction
        pred_rgb = np.zeros((350,600,3)) + 255
        pred_rgb[:,:,0] =  255                  # red component 
        pred_rgb[:,:,1] = -255*pred[:,:] + 255  # green component 
        pred_rgb[:,:,2] = -255*pred[:,:] + 255  # blue component 
    
        # overlay 
        overlay = 2*gt - pred
        overlay_rgb = np.zeros((350,600,3)) + 255
        overlay_rgb[:,:,0] =  -255*(overlay == 2) + 255    # red component is from gr
        overlay_rgb[:,:,1] =  -255*(overlay == -1) + 255   # green component 
        overlay_rgb[:,:,2] =  255 - 255*(overlay != 0)     # blue component 
        
        if (i == 0):     
            ax[i,0].set_title('Ground Truth (GT)',size=20)
            ax[i,1].set_title('UNet Prediction Map',size=20)
            ax[i,2].set_title('Prediction Map with GT Overlay',size=20)
        
        ax[i,0].imshow(gt_rgb)
        ax[i,0].text(590, 10, 'Projection '+projection, size=12,
        horizontalalignment='right',
        verticalalignment='top')
        ax[i,0].set_xticks([])
        ax[i,0].set_yticks([])

        ax[i,1].imshow(pred_rgb)
        ax[i,1].text(590, 10, 'Projection '+projection, size=12,
        horizontalalignment='right',
        verticalalignment='top')
        ax[i,1].set_xticks([])
        ax[i,1].set_yticks([])
    
        ax[i,2].imshow(overlay_rgb)
        ax[i,2].text(590, 10, 'Projection '+projection, size=12,
        horizontalalignment='right',
        verticalalignment='top')
        ax[i,2].set_xticks([])
        ax[i,2].set_yticks([])

# %% [markdown]
# Pick a record

# %%
mra_all = mra_trn + mra_val
j=8
print(mra_all[j])
# Out:
# MNI_0656

# %%
plot_all(j)

# %% [markdown]
# Test against a MRA record

# %%
# Display GT / Prediction overlay maps

for i in range(app.NO_PROJECTIONS):
    plot_sample(mra_all[j],gt_trn[i,j,:350,:600],pred_trn[i,j,:350,:600], i)

# %% [markdown]
# Display Results by Projection

# %%
i = 5

for j in range(len(mra_all)):
    plot_sample(mra_all[j],gt_trn[i,j,:350,:600],pred_trn[i,j,:350,:600], i)

# %% [markdown]
# End of Training Exercise
