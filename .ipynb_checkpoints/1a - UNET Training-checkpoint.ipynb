# %% [markdown]
# # Phase 1a - Training of 9 Neural Networks (U-Nets)
#
# Code framework from
# https://www.depends-on-the-definition.com/unet-keras-segmenting-images/ re-used and customised for the purposes of this project

# %%
import os
import math
import numpy as np
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline

import MRASegmentation as mra
import unets.UNetModels as un
import utils.support as sup

from keras.callbacks import EarlyStopping, ModelCheckpoint
# Out:
# /Users/rvh/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.
# No MRA scans are available and nothing can be processed. Set up source data in directory data/source/

# %% [markdown]
# We start by creating an instance for the MRA blood vessel segmentation process. Then we read in all the MRA Record ids for the provided cerebral MRA scans.

# %%
app = mra.MRASegmentation()
mra_all = app.get_mra_source_ids()

# %% [markdown]
# In the first step we create 9 image projections and corresponding projections of ground truth data for all 10 patient records that have been made available for this project.
# IMPORTANT: SET DEBUG=Yes in the ini-file, as data stored in this directory will be used by the training processes of the nine neural networks (UNETS). 1 UNET is trained for each image projection.

# %%
if not app._debug: 
    print ("Set the debug parameter to YES, prior to proceeding with this notebook")
    raise ValueError
else: 
    app.set_up_debug_directories (mra_all)
    for nme in mra_all:  
        app._mra_id = nme
        src = app.get_3d_mra_source(nme) 
        app.get_2d_mra_src_projs(src)
        gt = app.get_3d_mra_gt(nme)
        app.get_2d_mra_gt_projs(gt)
        print('Record '+nme+' processed successfully.')
# Out:
# Record MNI_0656 processed successfully.
# Record MNI_0657 processed successfully.
# Record MNI_0592 processed successfully.
# Record MNI_0643 processed successfully.
# Record MNI_0663 processed successfully.
# Record MNI_0664 processed successfully.
# Record MNI_0590 processed successfully.
# Record MNI_0591 processed successfully.
# Record MNI_0640 processed successfully.
# Record MNI_0648 processed successfully.

# %% [markdown]
# Split into training, validation and test data sets

# %%
mra_val = ['MNI_0656']   # the manually segmented record is used as validation record during training 
mra_trn = app.get_mra_source_ids()
mra_trn.remove('MNI_0656') # traning data set does not include the manually segmented record
mra_trn.remove('MNI_0663') # removed as MNI_0663 is not used during training (only during final testing in Phase 3)

# %% [markdown]
# Create an instance for the nine U-Nets

# %%
unets = un.MRA_UNets(app._model_path,
                    app._no_slices,
                    app._img_height,
                    app._img_width,
                    app.NO_PROJECTIONS,
                    app._unet_threshold)


# store the results of each training run in a dictionary for printing and further analysis 
results = dict() 


print('CAUTION: Any existing model coefficients in model path '+app._model_path+' will be overwritten if you proceed!!!')

# %% [markdown]
# The following process completes training for each of the nine projections in 10 - 15min on commodity hardware (MacBook Air, 8GB RAM). On this hardware, the entire training process completes in 2hours 30min. No GPU accelerations have been utilised.
#
# Important note: if you plan to start a clean new run, you should remove all the weightings for the neural networks in the 'models' folder. Otherwise, the process will run the weightings from the previous run and attempt to improve the model from there.

# %%
for i in range(app.NO_PROJECTIONS):  
    projection = str(i+1)
    print('********************************************')
    print('TRAINING NEURAL NETWORK FOR PROJECTION '+projection+'...')
    print('********************************************')
    # get padded image dimensions that should be used in neural network 
    h, w = unets.get_image_projection_size (projection)
 
    # Load the training data 
    src_trn = np.zeros((len(mra_trn), h, w, 1), dtype=np.float32) 
    gt_trn  = np.zeros((len(mra_trn), h, w, 1), dtype=np.float32) 
    j=0
    for f in mra_trn: 
        img = cv2.imread(app._debug_path + f +'/Step2 2D-Source-Projection-' + projection + '-CLAHE.jpg')
        ho, wo = unets.get_image_size (projection)
        x_img = sup.convert_image_to_grey(img,ho,wo)
        src_trn[j,:ho,:wo,0] = x_img / 255.0
        
        img = cv2.imread(app._debug_path + f +'/Step2 2D-GT-Projection-' + projection + '.jpg')
        ho, wo = unets.get_image_size (projection)
        x_img = sup.convert_image_to_grey(img,ho,wo)
        gt_trn[j,:ho,:wo,0] = x_img / 255.0
        j = j+1

    # Load the validation data 
    src_val = np.zeros((len(mra_val), h, w, 1), dtype=np.float32) 
    gt_val  = np.zeros((len(mra_val), h, w, 1), dtype=np.float32) 
    j=0
    for f in mra_val: 
        img = cv2.imread(app._debug_path + f +'/Step2 2D-Source-Projection-' + projection + '-CLAHE.jpg')
        ho, wo = unets.get_image_size (projection)
        x_img = sup.convert_image_to_grey(img,ho,wo)
        src_val[j,:ho,:wo,0] = x_img / 255.0
        
        img = cv2.imread(app._debug_path + f +'/Step2 2D-GT-Projection-' + projection + '.jpg')
        ho, wo = unets.get_image_size (projection)
        x_img = sup.convert_image_to_grey(img,ho,wo)
        gt_val[j,:ho,:wo,0] = x_img / 255.0
        j = j+1

    # initialise the U-Net for the p-th projection before starting the training run 
    model = unets.load_model(projection)
    model_par_file = app._model_path+'model-Projection-'+projection 
    # model.summary() if you want to display the summary of the UNET model 
    callbacks = [EarlyStopping(patience=10, verbose=1),
         ModelCheckpoint(model_par_file, verbose=1, save_best_only=True, save_weights_only=True)]
    # now start the training process for the p-th projection: 
    results[projection] = model.fit(src_trn, gt_trn, batch_size=1, epochs=50, callbacks=callbacks,
                    validation_data=(src_val, gt_val))
# Out:
# ********************************************
# TRAINING NEURAL NETWORK FOR PROJECTION 1...
# ********************************************
# Train on 8 samples, validate on 1 samples
# Epoch 1/50
# 8/8 [==============================] - 17s 2s/step - loss: 0.1014 - binary_accuracy: 0.8669 - val_loss: 0.1259 - val_binary_accuracy: 0.8860
#
# Epoch 00001: val_loss improved from inf to 0.12585, saving model to data/models-3/model-Projection-1
# Epoch 2/50
# 8/8 [==============================] - 14s 2s/step - loss: 0.0953 - binary_accuracy: 0.8675 - val_loss: 0.1290 - val_binary_accuracy: 0.8890
#
# Epoch 00002: val_loss did not improve from 0.12585
# Epoch 3/50
# 8/8 [==============================] - 13s 2s/step - loss: 0.0894 - binary_accuracy: 0.8683 - val_loss: 0.1263 - val_binary_accuracy: 0.8881
#
# Epoch 00003: val_loss did not improve from 0.12585
# Epoch 4/50
# 8/8 [==============================] - 14s 2s/step - loss: 0.0838 - binary_accuracy: 0.8691 - val_loss: 0.1561 - val_binary_accuracy: 0.8802
#
# Epoch 00004: val_loss did not improve from 0.12585
# Epoch 5/50
# 8/8 [==============================] - 14s 2s/step - loss: 0.0797 - binary_accuracy: 0.8695 - val_loss: 0.1210 - val_binary_accuracy: 0.8883
#
# Epoch 00005: val_loss improved from 0.12585 to 0.12096, saving model to data/models-3/model-Projection-1
# Epoch 6/50
# 8/8 [==============================] - 14s 2s/step - loss: 0.0753 - binary_accuracy: 0.8703 - val_loss: 0.1256 - val_binary_accuracy: 0.8868
#
# Epoch 00006: val_loss did not improve from 0.12096
# Epoch 7/50
# 8/8 [==============================] - 14s 2s/step - loss: 0.0714 - binary_accuracy: 0.8709 - val_loss: 0.1422 - val_binary_accuracy: 0.8822
#
# Epoch 00007: val_loss did not improve from 0.12096
# Epoch 8/50
# 8/8 [==============================] - 16s 2s/step - loss: 0.0683 - binary_accuracy: 0.8712 - val_loss: 0.1244 - val_binary_accuracy: 0.8864
#
# Epoch 00008: val_loss did not improve from 0.12096
# Epoch 9/50
# 8/8 [==============================] - 16s 2s/step - loss: 0.0660 - binary_accuracy: 0.8715 - val_loss: 0.1370 - val_binary_accuracy: 0.8851
#
# Epoch 00009: val_loss did not improve from 0.12096
# Epoch 10/50
# 8/8 [==============================] - 15s 2s/step - loss: 0.0629 - binary_accuracy: 0.8721 - val_loss: 0.1271 - val_binary_accuracy: 0.8883
#
# Epoch 00010: val_loss did not improve from 0.12096
# Epoch 11/50
# 8/8 [==============================] - 14s 2s/step - loss: 0.0611 - binary_accuracy: 0.8722 - val_loss: 0.1430 - val_binary_accuracy: 0.8815
#
# Epoch 00011: val_loss did not improve from 0.12096
# Epoch 12/50
# 8/8 [==============================] - 15s 2s/step - loss: 0.0586 - binary_accuracy: 0.8727 - val_loss: 0.1428 - val_binary_accuracy: 0.8837
#
# Epoch 00012: val_loss did not improve from 0.12096
# Epoch 13/50
# 8/8 [==============================] - 14s 2s/step - loss: 0.0562 - binary_accuracy: 0.8733 - val_loss: 0.1298 - val_binary_accuracy: 0.8862
#
# Epoch 00013: val_loss did not improve from 0.12096
# Epoch 14/50
# 8/8 [==============================] - 15s 2s/step - loss: 0.0543 - binary_accuracy: 0.8735 - val_loss: 0.1427 - val_binary_accuracy: 0.8837
#
# Epoch 00014: val_loss did not improve from 0.12096
# Epoch 15/50
# 8/8 [==============================] - 14s 2s/step - loss: 0.0529 - binary_accuracy: 0.8737 - val_loss: 0.1754 - val_binary_accuracy: 0.8793
#
# Epoch 00015: val_loss did not improve from 0.12096
# Epoch 00015: early stopping
# ********************************************
# TRAINING NEURAL NETWORK FOR PROJECTION 2...
# ********************************************
# Train on 8 samples, validate on 1 samples
# Epoch 1/50
# 8/8 [==============================] - 16s 2s/step - loss: 0.0741 - binary_accuracy: 0.8472 - val_loss: 0.1097 - val_binary_accuracy: 0.8830
#
# Epoch 00001: val_loss improved from inf to 0.10972, saving model to data/models-3/model-Projection-2
# Epoch 2/50
# 8/8 [==============================] - 12s 2s/step - loss: 0.0709 - binary_accuracy: 0.8474 - val_loss: 0.1136 - val_binary_accuracy: 0.8814
#
# Epoch 00002: val_loss did not improve from 0.10972
# Epoch 3/50
# 8/8 [==============================] - 11s 1s/step - loss: 0.0654 - binary_accuracy: 0.8484 - val_loss: 0.1086 - val_binary_accuracy: 0.8819
#
# Epoch 00003: val_loss improved from 0.10972 to 0.10865, saving model to data/models-3/model-Projection-2
# Epoch 4/50
# 8/8 [==============================] - 11s 1s/step - loss: 0.0610 - binary_accuracy: 0.8494 - val_loss: 0.1059 - val_binary_accuracy: 0.8829
#
# Epoch 00004: val_loss improved from 0.10865 to 0.10590, saving model to data/models-3/model-Projection-2
# Epoch 5/50
# 8/8 [==============================] - 11s 1s/step - loss: 0.0573 - binary_accuracy: 0.8498 - val_loss: 0.1057 - val_binary_accuracy: 0.8824
#
# Epoch 00005: val_loss improved from 0.10590 to 0.10568, saving model to data/models-3/model-Projection-2
# Epoch 6/50
# 8/8 [==============================] - 11s 1s/step - loss: 0.0543 - binary_accuracy: 0.8503 - val_loss: 0.1100 - val_binary_accuracy: 0.8818
#
# Epoch 00006: val_loss did not improve from 0.10568
# Epoch 7/50
# 8/8 [==============================] - 12s 1s/step - loss: 0.0521 - binary_accuracy: 0.8505 - val_loss: 0.1069 - val_binary_accuracy: 0.8823
#
# Epoch 00007: val_loss did not improve from 0.10568
# Epoch 8/50
# 8/8 [==============================] - 11s 1s/step - loss: 0.0499 - binary_accuracy: 0.8509 - val_loss: 0.1036 - val_binary_accuracy: 0.8835
#
# Epoch 00008: val_loss improved from 0.10568 to 0.10356, saving model to data/models-3/model-Projection-2
# Epoch 9/50
# 8/8 [==============================] - 11s 1s/step - loss: 0.0485 - binary_accuracy: 0.8508 - val_loss: 0.1104 - val_binary_accuracy: 0.8815
#
# Epoch 00009: val_loss did not improve from 0.10356
# Epoch 10/50
# 8/8 [==============================] - 11s 1s/step - loss: 0.0463 - binary_accuracy: 0.8512 - val_loss: 0.1127 - val_binary_accuracy: 0.8812
#
# Epoch 00010: val_loss did not improve from 0.10356
# Epoch 11/50
# 8/8 [==============================] - 11s 1s/step - loss: 0.0444 - binary_accuracy: 0.8515 - val_loss: 0.1090 - val_binary_accuracy: 0.8824
#
# Epoch 00011: val_loss did not improve from 0.10356
# Epoch 12/50
# 8/8 [==============================] - 12s 2s/step - loss: 0.0424 - binary_accuracy: 0.8518 - val_loss: 0.1085 - val_binary_accuracy: 0.8831
#
# Epoch 00012: val_loss did not improve from 0.10356
# Epoch 13/50
# 8/8 [==============================] - 13s 2s/step - loss: 0.0409 - binary_accuracy: 0.8523 - val_loss: 0.1139 - val_binary_accuracy: 0.8823
#
# Epoch 00013: val_loss did not improve from 0.10356
# Epoch 14/50
# 8/8 [==============================] - 11s 1s/step - loss: 0.0396 - binary_accuracy: 0.8524 - val_loss: 0.1162 - val_binary_accuracy: 0.8818
#
# Epoch 00014: val_loss did not improve from 0.10356
# Epoch 15/50
# 8/8 [==============================] - 11s 1s/step - loss: 0.0384 - binary_accuracy: 0.8526 - val_loss: 0.1126 - val_binary_accuracy: 0.8829
#
# Epoch 00015: val_loss did not improve from 0.10356
# Epoch 16/50
# 8/8 [==============================] - 13s 2s/step - loss: 0.0372 - binary_accuracy: 0.8528 - val_loss: 0.1173 - val_binary_accuracy: 0.8824
#
# Epoch 00016: val_loss did not improve from 0.10356
# Epoch 17/50
# 8/8 [==============================] - 13s 2s/step - loss: 0.0363 - binary_accuracy: 0.8531 - val_loss: 0.1181 - val_binary_accuracy: 0.8821
#
# Epoch 00017: val_loss did not improve from 0.10356
# Epoch 18/50
# 8/8 [==============================] - 12s 1s/step - loss: 0.0358 - binary_accuracy: 0.8530 - val_loss: 0.1177 - val_binary_accuracy: 0.8818
#
# Epoch 00018: val_loss did not improve from 0.10356
# Epoch 00018: early stopping
# ********************************************
# TRAINING NEURAL NETWORK FOR PROJECTION 3...
# ********************************************
# Train on 8 samples, validate on 1 samples
# Epoch 1/50
# 8/8 [==============================] - 16s 2s/step - loss: 0.1944 - binary_accuracy: 0.8168 - val_loss: 0.1866 - val_binary_accuracy: 0.8500
#
# Epoch 00001: val_loss improved from inf to 0.18664, saving model to data/models-3/model-Projection-3
# Epoch 2/50
# 8/8 [==============================] - 11s 1s/step - loss: 0.1817 - binary_accuracy: 0.8185 - val_loss: 0.1850 - val_binary_accuracy: 0.8465
#
# Epoch 00002: val_loss improved from 0.18664 to 0.18500, saving model to data/models-3/model-Projection-3
# Epoch 3/50
# 8/8 [==============================] - 12s 2s/step - loss: 0.1713 - binary_accuracy: 0.8205 - val_loss: 0.1655 - val_binary_accuracy: 0.8581
#
# Epoch 00003: val_loss improved from 0.18500 to 0.16550, saving model to data/models-3/model-Projection-3
# Epoch 4/50
# 8/8 [==============================] - 11s 1s/step - loss: 0.1630 - binary_accuracy: 0.8211 - val_loss: 0.1691 - val_binary_accuracy: 0.8559
#
# Epoch 00004: val_loss did not improve from 0.16550
# Epoch 5/50
# 8/8 [==============================] - 11s 1s/step - loss: 0.1558 - binary_accuracy: 0.8215 - val_loss: 0.1689 - val_binary_accuracy: 0.8518
#
# Epoch 00005: val_loss did not improve from 0.16550
# Epoch 6/50
# 8/8 [==============================] - 11s 1s/step - loss: 0.1499 - binary_accuracy: 0.8217 - val_loss: 0.1987 - val_binary_accuracy: 0.8338
#
# Epoch 00006: val_loss did not improve from 0.16550
# Epoch 7/50
# 8/8 [==============================] - 11s 1s/step - loss: 0.1430 - binary_accuracy: 0.8230 - val_loss: 0.1829 - val_binary_accuracy: 0.8411
#
# Epoch 00007: val_loss did not improve from 0.16550
# Epoch 8/50
# 8/8 [==============================] - 11s 1s/step - loss: 0.1364 - binary_accuracy: 0.8242 - val_loss: 0.1790 - val_binary_accuracy: 0.8417
#
# Epoch 00008: val_loss did not improve from 0.16550
# Epoch 9/50
# 8/8 [==============================] - 11s 1s/step - loss: 0.1313 - binary_accuracy: 0.8248 - val_loss: 0.1856 - val_binary_accuracy: 0.8362
#
# Epoch 00009: val_loss did not improve from 0.16550
# Epoch 10/50
# 8/8 [==============================] - 11s 1s/step - loss: 0.1274 - binary_accuracy: 0.8250 - val_loss: 0.1746 - val_binary_accuracy: 0.8417
#
# Epoch 00010: val_loss did not improve from 0.16550
# Epoch 11/50
# 8/8 [==============================] - 12s 2s/step - loss: 0.1241 - binary_accuracy: 0.8254 - val_loss: 0.1687 - val_binary_accuracy: 0.8408
#
# Epoch 00011: val_loss did not improve from 0.16550
# Epoch 12/50
# 8/8 [==============================] - 11s 1s/step - loss: 0.1192 - binary_accuracy: 0.8261 - val_loss: 0.1639 - val_binary_accuracy: 0.8430
#
# Epoch 00012: val_loss improved from 0.16550 to 0.16388, saving model to data/models-3/model-Projection-3
# Epoch 13/50
# 8/8 [==============================] - 11s 1s/step - loss: 0.1144 - binary_accuracy: 0.8272 - val_loss: 0.1618 - val_binary_accuracy: 0.8475
#
# Epoch 00013: val_loss improved from 0.16388 to 0.16177, saving model to data/models-3/model-Projection-3
# Epoch 14/50
# 8/8 [==============================] - 11s 1s/step - loss: 0.1102 - binary_accuracy: 0.8281 - val_loss: 0.1618 - val_binary_accuracy: 0.8470
#
# Epoch 00014: val_loss did not improve from 0.16177
# Epoch 15/50
# 8/8 [==============================] - 12s 1s/step - loss: 0.1070 - binary_accuracy: 0.8285 - val_loss: 0.1663 - val_binary_accuracy: 0.8436
#
# Epoch 00015: val_loss did not improve from 0.16177
# Epoch 16/50
# 8/8 [==============================] - 12s 1s/step - loss: 0.1049 - binary_accuracy: 0.8285 - val_loss: 0.1965 - val_binary_accuracy: 0.8365
#
# Epoch 00016: val_loss did not improve from 0.16177
# Epoch 17/50
# 8/8 [==============================] - 11s 1s/step - loss: 0.1029 - binary_accuracy: 0.8285 - val_loss: 0.1956 - val_binary_accuracy: 0.8345
#
# Epoch 00017: val_loss did not improve from 0.16177
# Epoch 18/50
# 8/8 [==============================] - 11s 1s/step - loss: 0.0995 - binary_accuracy: 0.8294 - val_loss: 0.1770 - val_binary_accuracy: 0.8426
#
# Epoch 00018: val_loss did not improve from 0.16177
# Epoch 19/50
# 8/8 [==============================] - 11s 1s/step - loss: 0.0964 - binary_accuracy: 0.8299 - val_loss: 0.1721 - val_binary_accuracy: 0.8429
#
# Epoch 00019: val_loss did not improve from 0.16177
# Epoch 20/50
# 8/8 [==============================] - 11s 1s/step - loss: 0.0933 - binary_accuracy: 0.8307 - val_loss: 0.1839 - val_binary_accuracy: 0.8394
#
# Epoch 00020: val_loss did not improve from 0.16177
# Epoch 21/50
# 8/8 [==============================] - 11s 1s/step - loss: 0.0904 - binary_accuracy: 0.8313 - val_loss: 0.1972 - val_binary_accuracy: 0.8365
#
# Epoch 00021: val_loss did not improve from 0.16177
# Epoch 22/50
# 8/8 [==============================] - 11s 1s/step - loss: 0.0892 - binary_accuracy: 0.8314 - val_loss: 0.1805 - val_binary_accuracy: 0.8389
#
# Epoch 00022: val_loss did not improve from 0.16177
# Epoch 23/50
# 8/8 [==============================] - 11s 1s/step - loss: 0.0864 - binary_accuracy: 0.8320 - val_loss: 0.1778 - val_binary_accuracy: 0.8399
#
# Epoch 00023: val_loss did not improve from 0.16177
# Epoch 00023: early stopping
# ********************************************
# TRAINING NEURAL NETWORK FOR PROJECTION 4...
# ********************************************
# Train on 8 samples, validate on 1 samples
# Epoch 1/50
# 8/8 [==============================] - 31s 4s/step - loss: 0.1288 - binary_accuracy: 0.8790 - val_loss: 0.1286 - val_binary_accuracy: 0.9070
#
# Epoch 00001: val_loss improved from inf to 0.12864, saving model to data/models-3/model-Projection-4
# Epoch 2/50
# 8/8 [==============================] - 24s 3s/step - loss: 0.1221 - binary_accuracy: 0.8802 - val_loss: 0.1083 - val_binary_accuracy: 0.9141
#
# Epoch 00002: val_loss improved from 0.12864 to 0.10828, saving model to data/models-3/model-Projection-4
# Epoch 3/50
# 8/8 [==============================] - 23s 3s/step - loss: 0.1157 - binary_accuracy: 0.8809 - val_loss: 0.1229 - val_binary_accuracy: 0.9064
#
# Epoch 00003: val_loss did not improve from 0.10828
# Epoch 4/50
# 1/8 [==>...........................] - ETA: 20s - loss: 0.1126 - binary_accuracy: 0.8788

# %% [markdown]
# Display results of learning curves for each of the nine projections

# %%
for i in range(app.NO_PROJECTIONS):
    projection = str(i+1)
    res = results[projection]
    plt.figure(figsize=(8, 8))
    plt.title("Learning Curve for Image Projection "+projection)
    plt.plot(res.history["loss"], label="Loss")
    plt.plot(res.history["val_loss"], label="Validation Loss")
    plt.plot( np.argmin(res.history["val_loss"]), np.min(res.history["val_loss"]), marker="x", color="r", label="Best Model")
    plt.xlabel("Epochs")
    plt.ylabel("Log Loss (Cross Entropy)")
    plt.legend();

# %% [markdown]
# End of Training Process
